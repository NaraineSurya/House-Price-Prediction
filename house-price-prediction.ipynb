# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# visualization
import matplotlib.pyplot as plt 
import seaborn as sns
# model building
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
#data = pd.read_csv("/kaggle/input/housing-dataset.csv")
housing = pd.DataFrame(pd.read_csv("/kaggle/input/housing-dataset/Housing.csv"))
housing.head()

# %%
# Getting the dimensions of the data
print(f"Rows and Columns of data is :{housing.shape}")

# %%
# Getting the null values of the data
housing.info()

# %%
housing.describe(include = 'all')

# %%
# Checking the null values
housing.isnull().sum()

# %%
#Outlier Analysis 
fig,axs = plt.subplots(2,3, figsize = (10,5))
plt1 = sns.boxplot(housing['price'], ax = axs[0,0], orient="h")
plt1 = sns.boxplot(housing['area'], ax = axs[0,1], orient="h")
plt1 = sns.boxplot(housing['bedrooms'], ax = axs[0,2], orient="h")
plt1 = sns.boxplot(housing['bathrooms'], ax = axs[1,0], orient="h")
plt1 = sns.boxplot(housing['stories'], ax = axs[1,1], orient="h")
plt1 = sns.boxplot(housing['parking'], ax = axs[1,2], orient="h")
plt.tight_layout()
